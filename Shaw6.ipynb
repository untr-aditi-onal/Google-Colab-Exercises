# %%
#this is a string where the formatted variable is 10 and it's also storing x
x = ("There are %d types of people." % 10)
#defining more variables to fill in strings for later when they're called
binary = "binary"
do_not = "don't"
#this is a string where the formatted variables are binary and don't and it's storing in y 
y = ("Those who know %s and those who %s." % (binary, do_not))
#printing the following variables defined above 
print (x)
print (y)
#this is a string inside a string after being initialized
print ("I said: %r." % x)
print ("I also said: '%s'." % y)

#the joke isn't funny 
hilarious = False
joke_evaluation = "Isn't that joke so funny?! %r"

#the desired output is the following...also this is the 3rd time a string is being put inside a string so there's not  4
print ("joke_evaluation % hilarious")

#defining variables
w = "This is the left side of..."
e = "a string with a right side."

#string concatenation 
print (w + e)
# Out:
# There are 10 types of people.
# Those who know binary and those who don't.
# I said: 'There are 10 types of people.'.
# I also said: 'Those who know binary and those who don't.'.
# joke_evaluation % hilarious
# This is the left side of...a string with a right side.
