# %% [markdown]
# # **Lab 01, MS059, Python and Viz**
# # Lab partners: Douglas Goodwin & MashaLu
#
# https://paper.dropbox.com/doc/Endangered-Species-Poster-Vaquita-qijQ4UXoxDQrkT3flj7U7

# %% [markdown]
# # Have you seen these posters from a 2008 campaign by World Wildlife Fund (WWF)? The campaign, called *WWF Japan – Population by Pixel*, was created by the agency Hakuhodo C&D / Tokyo. These pictures are composed of as many pixels as there are animals still alive in these species.
#
# ## The campaign featured several pixelated images of endangered animal species. The photos look blurry, like there is something wrong with the image (or your eyes).
#
# ## Read closer and discover that the pixels represent the total number of each species that remain on the Earth, one pixel for every individual. The blurrier the image, the fewer animals remain. This campaign delivers an emotional response that brings focus to the endangered species problem and does it with technology.
#
# ![](https://www.evernote.com/l/ADMY-ua94K9D_b-Ggu2bjKMfGIKAUE5JZ4MB/image.png)
#
# # Your job is to reproduce this campaign in Python and make images containing the same number of pixels as the animals that remain in the wild.
#
# After everyone is set up I will send you by pairs into breakout rooms.
#
# 1. Select an image of an individual animal from an endangered species. Start with one of the prepared images below.
# 2. Open a copy of the Colab notebook. Put your names at the top!
# Change the values for `cnt` the count of remaining animals and `msg` the caption.
# 3. Make posters!
# 4. Add comments on your experience to the notebook and share it with my Google account: dgoodwin@gmail.com and paste it into this assignment.
# 5. Upload your JPGs with this form.
#
# I encourage you to find your own images. Make a 400x400 pixel version and upload it to Colab. You may also use your own font.
#
# # This lab is due before midnight on the day it was assigned. I encourage you to finish it in class.

# %% [markdown]
# # Resources
#
# ## Here is a 400x400 pixel image of a Giant Panda from the WWF:
#
# ![](https://www.evernote.com/l/ADOw2tfbp7lE8p-f7yxcK74ghHwVuvR4v0IB/image.png)
#
# ## A 400x400 pixel image contains 400x400 or 160,000 total pixels. If there were 160,000 Giant Pandas in the world your image would look like the one above.
#
# ## But there are only 1,864 surviving giant pandas. How will you make the image contain only 1,864 pixels?
#
# ## This is a square image, so you may use a square root to determine the number of columns and rows that your image should have.
#
# # $rows = cols = int(\sqrt{survivors})$
# # $rows = cols = 43$
#
# # Round the columns and rows to the nearest whole number and you get an image that looks like this:
#
# ![](https://www.evernote.com/l/ADMPyPyWKb1N_r1ZrWxac3XOnlRuJX7JP8YB/image.png)
#
# (Note that 43x43 is 1849, close enough for our purposes.)
#
#
# # There actually isn't a lot of Python to learn here because you are leaning on the existing image matrix to store the values. Collapse it to match the endangered population and then expand it using the NEAREST NEIGHBOR algorithm. It's a beautiful cheat that will encourage you to think about images as data-stores.
#
# ## What if you had to keep track of that matrix and draw each each large pixel on the screen? Let's do that in Processing.py after we make a few images.
#
# ---

# %% [markdown]
# # Here is a list of endangered species with current populations for these animals.
#
# https://www.wanderlust.co.uk/content/10-of-the-worlds-most-endangered-animals/
#
#
# ## Here are several 400x400 pixel images of endangered animals:
#
# ```
# pandaUrl   = 'https://www.evernote.com/l/ADOw2tfbp7lE8p-f7yxcK74ghHwVuvR4v0IB/image.png'
# jaguarUrl  = 'https://www.evernote.com/l/ADNsAD0jWDtGvYq4I85KOUQXz9HDwCN4M-YB/image.png'
# gorillaUrl = 'https://www.evernote.com/l/ADOdBwKmLZ5G6q8ClR2-Ru50tWj_v6cgofkB/image.png'
# rhinoUrl   = 'https://www.evernote.com/l/ADNAollR6kFPzrtD0ETXuZ9ycRSraoijuCYB/image.png'
# leopardUrl = 'https://www.evernote.com/l/ADMNhBAFfAdL9r0WZRstcqQ9XqIcDuN82b0B/image.png'
# orangUrl   = 'https://www.evernote.com/l/ADOG4tgj-WpHVaH-F5O4z4lMJzdSQDzHl10B/image.png'
# ```

# %%
# Get the font with a system call to `wget`
! wget -q 'https://github.com/topfunky/sparklines/raw/master/fonts/silkscreen/slkscr.ttf'

# %%
# Import all of the libraries you need
from PIL import Image, ImageDraw, ImageFont # Open and manipulate images on the server
from math import sqrt                       # Function to get the square root of a number
import requests                             # Download images
import matplotlib.pyplot as plt             # Make plots with Python

# use a truetype font
fnt = ImageFont.truetype('slkscr.ttf', 21)
bfnt = ImageFont.truetype('slkscr.ttf', 72)

# %% [markdown]
# # Make Image objects from the URLs:

# %%
pandaUrl   = 'https://www.evernote.com/l/ADOw2tfbp7lE8p-f7yxcK74ghHwVuvR4v0IB/image.png'
jaguarUrl  = 'https://www.evernote.com/l/ADNsAD0jWDtGvYq4I85KOUQXz9HDwCN4M-YB/image.png'
gorillaUrl = 'https://www.evernote.com/l/ADOdBwKmLZ5G6q8ClR2-Ru50tWj_v6cgofkB/image.png'
rhinoUrl   = 'https://www.evernote.com/l/ADNAollR6kFPzrtD0ETXuZ9ycRSraoijuCYB/image.png'
leopardUrl = 'https://www.evernote.com/l/ADMNhBAFfAdL9r0WZRstcqQ9XqIcDuN82b0B/image.png'
orangUrl   = 'https://www.evernote.com/l/ADOG4tgj-WpHVaH-F5O4z4lMJzdSQDzHl10B/image.png'

panda = Image.open(requests.get(pandaUrl, stream=True).raw)
jaguar = Image.open(requests.get(jaguarUrl, stream=True).raw)
gorilla = Image.open(requests.get(gorillaUrl, stream=True).raw)
rhino = Image.open(requests.get(rhinoUrl, stream=True).raw)
orang = Image.open(requests.get(orangUrl, stream=True).raw)

# %% [markdown]
# # Look at the panda Image:

# %%
# Look at one of the images
plt.imshow(panda)

# %% [markdown]
# # Can you make it bigger? Sure--change the figure size to 10x10

# %%
# Note the ticks: they count the rows and columns of pixels. 
# There are 400x400 pixels in this image, a total of 160,000 make a nice crisp picture. 


fig = plt.figure(figsize=(10,10))
plt.imshow(panda)

# %% [markdown]
# # How do you reduce the number of pixels?
#
# How many giant pandas are left?
#
# # Set up your count and message. Get the data right!
# # At least count (2014 census) there were 1,864 giant pandas living in the wild.
#
# # $rows = cols = int(\sqrt{1864})$
# # $rows = cols = 43$
#
#
#
#
# `cnt = 1864`
#
# `msg = "Giant Pandas."`

# %%
# How do you reduce the number of pixels? 
# Resize it to 50x50 pixels

cnt = 1864
msg = "Giant Pandas."

rows = cols = int(sqrt(cnt))  # Note that rows equal to cols 
                              # because it's a square root and we want a square Image
                              # Also that both are integers!

print(rows,cols)

coarse = panda.resize((cols,rows))
plt.imshow(coarse)

# %% [markdown]
# # Resize the Image to 400x400 pixels

# %%
# Bring it back to 400x400 pixels

# yes, you need to call figure() every time!
fig = plt.figure(figsize=(10,10))

coarse400x400 = coarse.resize((400,400))
plt.imshow(coarse400x400)

# %% [markdown]
# # Yuck!
#
# ## Use resample=Image.NEAREST prevents the Python Image Library (PIL)

# %%
# Yuck!
# Use resample=Image.NEAREST prevents the Python Image Library (PIL) 
# from smoothing out your image

# yes, you need to call figure() every time!
fig = plt.figure(figsize=(10,10))

coarse400x400 = coarse.resize((400,400),resample=Image.NEAREST)
plt.imshow(coarse400x400)

# %% [markdown]
# # Add an annotation

# %%
# Add an annotation

# yes, you need to call figure() every time!
fig = plt.figure(figsize=(10,10))

# Set up your count and message. Get the data right!
# At least count (2014 census) there were 1,864 giant pandas living in the wild.
cnt = 1864
msg = "Giant Pandas."

# Configure the truetype font ([Silkscreen, by Jason Kottke](https://kottke.org/plus/type/silkscreen/)) that you downloaded
fnt = ImageFont.truetype('slkscr.ttf', 21)
bfnt = ImageFont.truetype('slkscr.ttf', 72)

# Set up a Draw object
draw  = ImageDraw.Draw(coarse400x400)
# Draw two lines of text with the specified fill color and font
draw.text( (10,300), str(cnt), fill='#E8CeB7', font=bfnt)
draw.text( (10,360), msg, fill='#E8CeB7', font=fnt)

# Let's see!
plt.imshow(coarse400x400)

# %%
# Great! Save it.
coarse400x400.save('coarse400x400.png')

# %% [markdown]
# # The image was saved to your project folder. Download it before you close this session!
#
# ![](https://www.evernote.com/l/ADP1B3fm5-hBGqLiBeA9K57sBO2TZTuUxmoB/image.png)

# %% [markdown]
# # Great! Keep playing with images until you make a poster that you like.
#
# # Want more?
# ## Try making a 1080x1080 image for Instagram. Here's a start:

# %%
# Make an image for Instagram
## They prefer JPEG images at 1080x1080 pixels
##

# yes, you need to call figure() every time!
fig = plt.figure(figsize=(10,10))

instagram = coarse.resize((1080,1080),resample=Image.NEAREST)
plt.imshow(instagram)

# Use the Image's save() method
instaRGB = instagram.convert('RGB')     # Oops, you started with a PNG? 
                                        # Collapse the Alpha channel
instaRGB.save("panda_insta.jpg")
