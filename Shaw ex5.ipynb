# %%
# -*- coding: utf-8 -*-
my_name = 'Aditi Madhok'
my_age = 19  
my_height = 66 # inches
my_weight = 135 # lbs
my_eyes = 'Brown'
my_teeth = 'White'
my_hair = 'Black'

print ("She's %d inches tall." % my_height)
print ("She's %d pounds heavy." % my_weight)
print ("Actually that's not too heavy.")
print ("She's got %s eyes and %s hair." % (my_eyes, my_hair))
print ("Her teeth are usually %s depending on if she brushed her tooth or not." % my_teeth)

# this line is tricky, try to get it exactly right
print ("If I add %d, %d, and %d I get %d." % (
    my_age, my_height, my_weight, my_age + my_height + my_weight))
# Out:
# She's 66 inches tall.
# She's 135 pounds heavy.
# Actually that's not too heavy.
# She's got Brown eyes and Black hair.
# Her teeth are usually White depending on if she brushed her tooth or not.
# If I add 19, 66, and 135 I get 220.

# %%
# inches -> cm
my_height = 66 # inches 
cm = 0.393701 
print (my_height * cm)
# Out:
# 25.984266

# %%
# pounds -> kilograms
my_weight = 135 # lbs
kg = 2.20462
print (my_weight * kg)
# Out:
# 297.6237
