# %%
def hello():
    print('Howdy!')
    print('Howdy!!!')
    print('Hello there.')

hello()
hello()
hello()
# Out:
# Howdy!
# Howdy!!!
# Hello there.
# Howdy!
# Howdy!!!
# Hello there.
# Howdy!
# Howdy!!!
# Hello there.

# %%
def hello(name):
    print('Hello, ' + name)

hello('Alice')
hello('Bob')
# Out:
# Hello, Alice
# Hello, Bob

# %%
def sayHello(name):
       print('Hello, ' + name)
sayHello('Al')
# Out:
# Hello, Al

# %%
import random

def getAnswer(answerNumber):
       if answerNumber == 1:
           return 'It is certain'
       elif answerNumber == 2:
           return 'It is decidedly so'
       elif answerNumber == 3:
           return 'Yes'
       elif answerNumber == 4:
           return 'Reply hazy try again'
       elif answerNumber == 5:
           return 'Ask again later'
       elif answerNumber == 6:
           return 'Concentrate and ask again'
       elif answerNumber == 7:
           return 'My reply is no'
       elif answerNumber == 8:
           return 'Outlook not so good'
       elif answerNumber == 9:
           return 'Very doubtful'

r = random.randint(1, 9)
fortune = getAnswer(r)
print(fortune)
# Out:
# Yes

# %%
spam = print('Hello!')
None == spam
# Out:
# Hello!
# True

# %%
print('Hello')
print('World')
# Out:
# Hello
# World

# %%
print('Hello', end='')
print('World')
# Out:
# HelloWorld

# %%
print('cats', 'dogs', 'mice')
# Out:
# cats dogs mice

# %%
print('cats', 'dogs', 'mice', sep=',')
# Out:
# cats,dogs,mice

# %%
   def a():
       print('a() starts')
       b()
       d()
       print('a() returns')

   def b():
       print('b() starts')
       c()
       print('b() returns')

   def c():
       print('c() starts')
       print('c() returns')

   def d():
       print('d() starts')
       print('d() returns')

   a()
# Out:
# a() starts
# b() starts
# c() starts
# c() returns
# b() returns
# d() starts
# d() returns
# a() returns

# %%
def spam():
   eggs = 31337
spam()
print(eggs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-7e5dc5c222c2> in <module>()
#       2    eggs = 31337
#       3 spam()
# ----> 4 print(eggs)
#
# NameError: name 'eggs' is not defined

# %%
def spam():
     eggs = 99
     bacon()
     print(eggs)

def bacon():
       ham = 101
       eggs = 0

spam()
# Out:
# 99

# %%
def spam():
    print(eggs)
eggs = 42
spam()
print(eggs)
# Out:
# 42
# 42

# %%
def spam():
       eggs = 'spam local'
       print(eggs)    # prints 'spam local'

def bacon():
       eggs = 'bacon local'
       print(eggs)    # prints 'bacon local'
       spam()
       print(eggs)    # prints 'bacon local'

eggs = 'global'
bacon()
print(eggs)        # prints 'global'
# Out:
# bacon local
# spam local
# bacon local
# global

# %%
def spam():
  global eggs
  eggs = 'spam'

eggs = 'global'
spam()
print(eggs)
# Out:
# spam

# %%
def spam():
     global eggs
     eggs = 'spam' # this is the global

def bacon():
     eggs = 'bacon' # this is a local

def ham():
     print(eggs) # this is the global

eggs = 42 # this is the global
spam()
print(eggs)
# Out:
# spam

# %%
def spam():
       print(eggs) # ERROR!
       eggs = 'spam local'

eggs = 'global'
spam()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-8-40bcd993911c> in <module>()
#       4
#       5 eggs = 'global'
# ----> 6 spam()
#
# <ipython-input-8-40bcd993911c> in spam()
#       1 def spam():
# ----> 2        print(eggs) # ERROR!
#       3        eggs = 'spam local'
#       4
#       5 eggs = 'global'
#
# UnboundLocalError: local variable 'eggs' referenced before assignment

# %%
def spam(divideBy):
    return 42 / divideBy

print(spam(2))
print(spam(12))
print(spam(0))
print(spam(1))
# Out:
# 21.0
# 3.5
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-cce18d473349> in <module>()
#       4 print(spam(2))
#       5 print(spam(12))
# ----> 6 print(spam(0))
#       7 print(spam(1))
#
# <ipython-input-9-cce18d473349> in spam(divideBy)
#       1 def spam(divideBy):
# ----> 2     return 42 / divideBy
#       3
#       4 print(spam(2))
#       5 print(spam(12))
#
# ZeroDivisionError: division by zero

# %%
def spam(divideBy):
    try:
        return 42 / divideBy
    except ZeroDivisionError:
        print('Error: Invalid argument.')

print(spam(2))
print(spam(12))
print(spam(0))
print(spam(1))
# Out:
# 21.0
# 3.5
# Error: Invalid argument.
# None
# 42.0

# %%
def spam(divideBy):
    return 42 / divideBy

try:
    print(spam(2))
    print(spam(12))
    print(spam(0))
    print(spam(1))
except ZeroDivisionError:
    print('Error: Invalid argument.')
# Out:
# 21.0
# 3.5
# Error: Invalid argument.

# %%
import time, sys
indent = 0 # How many spaces to indent.
indentIncreasing = True # Whether the indentation is increasing or not.

try:
    while True: # The main program loop.
        print(' ' * indent, end='')
        print('********')
        time.sleep(0.1) # Pause for 1/10 of a second.

        if indentIncreasing:
            # Increase the number of spaces:
            indent = indent + 1
            if indent == 20:
                # Change direction:
                indentIncreasing = False

        else:
            # Decrease the number of spaces:
            indent = indent - 1
            if indent == 0:
                # Change direction:
                indentIncreasing = True
except KeyboardInterrupt:
    sys.exit()
# Out:
#      ********
#       ********
#        ********
#         ********
#          ********
#           ********
#            ********
#             ********
#              ********
#               ********
#                ********
#                 ********
#                  ********
#                   ********
#                    ********
#                     ********
#                    ********
#                   ********
#                  ********
#                 ********
#                ********
#               ********
#              ********
#             ********
#            ********
#           ********
#          ********
#         ********
#        ********
#       ********
#      ********
#     ********
#    ********
#   ********
#  ********
# ********
#  ********
#   ********
#    ********
#     ********
#      ********
#       ********
#        ********
#         ********
#          ********
#           ********
#            ********
#             ********
# ...

# %%
for deduplicating that could get tedious when changing code that is buggy so it groups code that gets executed multiple times
called
define
its the parantheses after the function, can have arguments...code executes where it is called and runs the returned value
for debugging codes and see which variables caused errors
1 each
they get destroyed and the variables that were created get forgotten
return value is what the expression evaluates to, depends on what argument its passing
none
its undefined
use the global statement 
NoneType with a capital N like Booleans of true and false...its the abscense of a value, can be useful when you want to store a nonreal value as a variable as it just returns none instead of evaluating
it imports exactly what follows after the import function statement
with a spam.bacon
using try and except clauses
depends on what you're testing, try is what you want to be executed and except catches the errors...You put what might cause an error in the “try”, you put what you know is going to work in the “except”
