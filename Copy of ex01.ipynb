# %%
print("Am i doing this right?")
print("Why isn't this working?")
print('I need "help" sigh')
print ("Oh jk yay is it now!")
print ("testing out escaping double apostrophes in python: 7 is 10\" of 70")
print ("Let's try emojis")
print("\U0001f600") 
print ("\U0001F40D")
# Out:
# Am i doing this right?
# Why isn't this working?
# I need "help" sigh
# Oh jk yay is it now!
# testing out escaping double apostrophes in python: 7 is 10" of 70
# Let's try emojis
# 😀
# 🐍

# %%
for x in range (0,10:)
  print("hi")
