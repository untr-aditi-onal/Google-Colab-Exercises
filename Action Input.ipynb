# %%
action = ''
while  True:
  print('What do you do in 8 minutes and 46 seconds?')
  action = input()
  if action == 'gardening':
    print('insert environmental injustice spatial map here')
  elif action == 'shopping':
    print('insert black businesses arts spatial map here')
  elif action == 'eating':
    print('insert food desert spatial map here')
  elif action == 'meditating':
    print('insert racial trauma hotline here')
  else:
    print('explore more')
    #break
# Out:
# What do you do in 8 minutes and 46 seconds?
# gardening
# insert environmental injustice spatial map here
# What do you do in 8 minutes and 46 seconds?
# shopping
# insert black businesses arts spatial map here
# What do you do in 8 minutes and 46 seconds?
# eating
# insert food desert spatial map here
# What do you do in 8 minutes and 46 seconds?
# meditating
# insert racial trauma hotline here
# What do you do in 8 minutes and 46 seconds?
# running
# explore more
# What do you do in 8 minutes and 46 seconds?
