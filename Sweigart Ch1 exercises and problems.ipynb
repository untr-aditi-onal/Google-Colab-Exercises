# %%
>>> 2 + 2
# Out:
# 4

# %%
>>> 2 + 3 * 6
# Out:
# 20

# %%
>>> (2 + 3) * 6
# Out:
# 30

# %%
>>> 48565878 * 578453
# Out:
# 28093077826734

# %%
>>> 2 ** 8
# Out:
# 256

# %%
>>> 23 / 7
# Out:
# 3.2857142857142856

# %%
>>> 23 // 7
# Out:
# 3

# %%
>>> 23 % 7
# Out:
# 2

# %%
>>> 2      +           2
# Out:
# 4

# %%
>>> (5 - 1) * ((7 + 1) / (3 - 1))
# Out:
# 16.0

# %%
>>> 5 +
# Out:
#   File "<ipython-input-13-4f4744a157be>", line 1
#     5 +
#        ^
# SyntaxError: invalid syntax

# %%
>>> 42 + 5 + * 2
# Out:
#   File "<ipython-input-14-16e07b76f178>", line 1
#     42 + 5 + * 2
#              ^
# SyntaxError: invalid syntax

# %%
>>> 'Hello, world!
# Out:
#   File "<ipython-input-15-ca3998db7a18>", line 1
#     'Hello, world!
#                   ^
# SyntaxError: EOL while scanning string literal

# %%
>>> 'Hello, world!'
# Out:
# 'Hello, world!'

# %%
>>> 'Alice' + 'Bob'
# Out:
# 'AliceBob'

# %%
>>> 'Alice' + 42
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-4e9a9e71481a> in <module>()
# ----> 1 'Alice' + 42
#
# TypeError: must be str, not int

# %%
>>> 'Alice' * 5
# Out:
# 'AliceAliceAliceAliceAlice'

# %%
>>> 'Alice' * 'Bob'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-9caa30780052> in <module>()
# ----> 1 'Alice' * 'Bob'
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
>>> 'Alice' * 5.0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-43325524c797> in <module>()
# ----> 1 'Alice' * 5.0
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
>>> spam = 40
>>> spam
# Out:
# 40

# %%
 >>> eggs = 2
>>> spam + eggs
# Out:
# 42

# %%
   >>> spam + eggs + spam
# Out:
# 82

# %%
>>> spam = spam + 2
>>> spam
# Out:
# 42

# %%
>>> spam = 'Hello'
>>> spam
# Out:
# 'Hello'

# %%
>>> spam = 'Goodbye'
>>> spam
# Out:
# 'Goodbye'

# %%
print('Hello, world!')
print('What is your name?')    # ask for their name
myName= input()
print('It is good to meet you, ' + myName)
print('The length of your name is:')
print(len(myName))
print('What is your age?')    # ask for their age
myAge = input()
print('You will be ' + str(int(myAge) + 1) + ' in a year.')
# Out:
# Hello, world!
# What is your name?
# Aditi
# It is good to meet you, Aditi
# The length of your name is:
# 5
# What is your age?
# 19
# You will be 20 in a year.

# %%
>>> str(29)
'29'
>>> print('I am ' + str(29) + ' years old.')
# Out:
# I am 29 years old.

# %%
>>> str(0)
# Out:
# '0'

# %%
>>> str(-3.14)
# Out:
# '-3.14'

# %%
>>> int('42')
# Out:
# 42

# %%
>>> int('-99')
# Out:
# -99

# %%
>>> int(1.25)
# Out:
# 1

# %%
>>> int(1.99)
# Out:
# 1

# %%
>>> float('3.14')
# Out:
# 3.14

# %%
>>> float(10)
# Out:
# 10.0

# %%
>>> spam = input()
101
>>> spam
# Out:
# 101
# '101'

# %%
>>> spam = int(spam)
>>> spam
# Out:
# 101

# %%
>>> spam * 10 / 5
# Out:
# 202.0

# %%
Practice Questions
1. operators: *, -, /, + values:'hello', -88.8,5
2. spam is variable, 'spam' is string (because in single quotation marks)
3. integers, strings, floating point nubmers
4. they all evaluate and they're made up of values and operators
5. altho they also share operators like an = sign but not required too, these r used more for variables than values so it can store the information
6. 21
7. 'spamspamspam'
8. can't begin with nubmer and needs letters
9. str(), int(), and float() 
10. 99 is an integer number and needs to be converted into a string
# Out:
#   File "<ipython-input-59-b413dbda0e3d>", line 1
#     Practice Questions
#                      ^
# SyntaxError: invalid syntax

# %%
11.
round (2.6)
# Out:
# 3
